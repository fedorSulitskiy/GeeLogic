# %%
import ee
import geemap
# Out:
# c:\Users\fsuli\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
geemap.ee_initialize()

# %%
Map = geemap.Map()

# %%
Map = geemap.Map(center=[40, -100], zoom=4, height=600)
Map
# Out:
# Map(center=[40, -100], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(T…

# %%
Map = geemap.Map(center=[21.79, 70.87], zoom=3)
image = ee.Image('USGS/SRTMGL1_003')
vis_params = {
    'min': 0,
    'max': 6000,
    'palette': ['006633', 'E5FFCC', '662A00', 'D8D8D8', 'F5F5F5'],
}
Map.addLayer(image, vis_params, 'SRTM')
Map
# Out:
# Map(center=[21.79, 70.87], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(childre…

# %%
import ipyleaflet
m = ipyleaflet.Map()
m
# Out:
# Map(center=[0.0, 0.0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %%
import os

current_directory = os.getcwd()

download_dir = os.path.abspath(os.path.join(current_directory, '../golden_eye_draft/assets'))
print(download_dir)
# Out:
# C:\Users\fsuli\Programming\100PROJECTS\GIS-GEE-Project\golden_eye_draft\assets

# %%
html_file = os.path.join(download_dir, 'my_map_one.html')
Map.to_html(filename=html_file, title='My Map', width='100%', height='300px')

# %%
import sys
print(sys.version)
# Out:
# 3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]

# %%
from ipywidgets import HTML

print(HTML(value = Map.to_html()).value)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>My Map</title>
# </head>
# <body>
#
#
# <!-- Load require.js. Delete this if your page already loads require.js -->
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.4/require.min.js" integrity="sha256-Ae2Vz/4ePdIu6ZyI/5ZGsYnb+m0JlOmKPjt6XZ9JJkA=" crossorigin="anonymous"></script>
# <script src="https://unpkg.com/@jupyter-widgets/html-manager@^0.20.0/dist/embed-amd.js" crossorigin="anonymous"></script>
#
# <script type="application/vnd.jupyter.widget-state+json">
# {
#   "version_major": 2,
#   "version_minor": 0,
#   "state": {
#     "fdbe45f6c396417991d439a3c724820e": {
#       "model_name": "LeafletMapStyleModel",
#       "model_module": "jupyter-leaflet",
#       "model_module_version": "^0.17",
#       "state": {}
#     },
#     "a5dfa6692266408696c246032e9f03fd": {
#       "model_name": "LeafletMapStyleModel",
#       "model_module": "jupyter-leaflet",
#       "model_module_version": "^0.17",
#       "state": {
#         "cursor": "move"
#       }
#     },
#     "b51fec4c6aeb4dbba3356f30bd4d0a1a": {
#       "model_name": "LeafletTileLayerModel",
#       "model_module": "jupyter-leaflet",
#       "model_module_version": "^0.17",
#       "state": {
#         "attribution": "&copy; <a href=\"https://www.openstreetmap.org/copyright\">OpenStreetMap</a> contributors",
#         "base": true,
#         "max_zoom": 19,
#         "min_zoom": 1,
#         "name": "OpenStreetMap.Mapnik",
#         "options": [
#           "attribution",
#           "bounds",
#           "detect_retina",
#           "max_native_zoom",
#           "max_zoom",
#           "min_native_zoom",
#           "min_zoom",
#           "no_wrap",
#           "tile_size",
#           "tms",
#           "zoom_offset"
#         ],
#         "subitems": [],
#         "url": "https://tile.openstreetmap.org/{z}/{x}/{y}.png"
#       }
#     },
#     "15f3d8a3bd6f4c4e9cf53ffdd9709ffe": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {
#         "height": "880px",
#         "width": "100%"
#       }
#     },
#     "3a4aacb760b84fe1a6dc39c45dd91954": {
#       "model_name": "LeafletMapStyleModel",
#       "model_module": "jupyter-leaflet",
#       "model_module_version": "^0.17",
#       "state": {}
#     },
#     "63491f137df4446fb27e9177d8a54663": {
#       "model_name": "LeafletMapModel",
#       "model_module": "jupyter-leaflet",
#       "model_module_version": "^0.17",
#       "state": {
#         "_dom_classes": [],
#         "bottom": 775.0,
#         "center": [
#           12.897489183755892,
#           169.80468750000003
#         ],
#         "controls": [
#           "IPY_MODEL_5e0dc5710d9548b7aa3e43030ffbef33",
#           "IPY_MODEL_cd78e4f38ee3400fa37e0ae6714eb8c8",
#           "IPY_MODEL_e3c08e3abfb24560bac75965b8ba51b5",
#           "IPY_MODEL_111f070b77674428bd20e5ca4da4e1e2",
#           "IPY_MODEL_635fa97945534a39af685a8582481b98",
#           "IPY_MODEL_de3b1bc0c39d413f91203f3f7330c5e6",
#           "IPY_MODEL_0aef6fa213584c05ad4ca1708f4e2e60",
#           "IPY_MODEL_5f12660e0586463895d2388bb617f3d2",
#           "IPY_MODEL_f5d57eec294a45b882f832b879998233"
#         ],
#         "crs": {
#           "name": "EPSG3857",
#           "custom": false
#         },
#         "default_style": "IPY_MODEL_fdbe45f6c396417991d439a3c724820e",
#         "dragging_style": "IPY_MODEL_a5dfa6692266408696c246032e9f03fd",
#         "east": 377.92968750000006,
#         "layers": [
#           "IPY_MODEL_b51fec4c6aeb4dbba3356f30bd4d0a1a",
#           "IPY_MODEL_ebe11ee949aa416ebf50197cbc291dad",
#           "IPY_MODEL_5dea01f46cfe4f169d746b0bba05397c"
#         ],
#         "layout": "IPY_MODEL_15f3d8a3bd6f4c4e9cf53ffdd9709ffe",
#         "left": 403.0,
#         "max_zoom": 24.0,
#         "north": 75.58493740869223,
#         "options": [
#           "bounce_at_zoom_limits",
#           "box_zoom",
#           "center",
#           "close_popup_on_click",
#           "double_click_zoom",
#           "dragging",
#           "fullscreen",
#           "inertia",
#           "inertia_deceleration",
#           "inertia_max_speed",
#           "interpolation",
#           "keyboard",
#           "keyboard_pan_offset",
#           "keyboard_zoom_offset",
#           "max_zoom",
#           "min_zoom",
#           "prefer_canvas",
#           "scroll_wheel_zoom",
#           "tap",
#           "tap_tolerance",
#           "touch_zoom",
#           "world_copy_jump",
#           "zoom",
#           "zoom_animation_threshold",
#           "zoom_delta",
#           "zoom_snap"
#         ],
#         "panes": {},
#         "right": 1587.0,
#         "scroll_wheel_zoom": true,
#         "south": -67.47492238478702,
#         "style": "IPY_MODEL_fdbe45f6c396417991d439a3c724820e",
#         "top": 175.0,
#         "west": -38.3203125,
#         "window_url": "vscode-webview://14dupdeqkmkea7qvq9mgb2ia8i2us04ig45t9vfahcr4dte3mlig/index.html?id=e402c3d9-9be6-4edc-a021-80bad1ccef4b&origin=e1788d0b-296a-4924-aadb-3c5aa63906d3&swVersion=4&extensionId=&platform=electron&vscode-resource-base-authority=vscode-resource.vscode-cdn.net&parentOrigin=vscode-file%3A%2F%2Fvscode-app&purpose=notebookRenderer",
#         "zoom": 2.0
#       }
#     },
#     "4276809000744490a3e9d2c728495258": {
#       "model_name": "LeafletZoomControlModel",
#       "model_module": "jupyter-leaflet",
#       "model_module_version": "^0.17",
#       "state": {
#         "options": [
#           "position",
#           "zoom_in_text",
#           "zoom_in_title",
#           "zoom_out_text",
#           "zoom_out_title"
#         ]
#       }
#     },
#     "317d8abd5b9e484e88a9140f95341be0": {
#       "model_name": "LeafletAttributionControlModel",
#       "model_module": "jupyter-leaflet",
#       "model_module_version": "^0.17",
#       "state": {
#         "options": [
#           "position",
#           "prefix"
#         ],
#         "position": "bottomright"
#       }
#     },
#     "cafadfef88ef463fb8278bed3ea633b0": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {
#         "width": "500px"
#       }
#     },
#     "2f207a4b4be4440d8e87820f6a4efee3": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {
#         "height": "28px",
#         "padding": "0px 0px 0px 4px",
#         "width": "28px"
#       }
#     },
#     "5887172a8a8645cd9381d415f166a58f": {
#       "model_name": "DescriptionStyleModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {}
#     },
#     "b0336fc0f3a340f2b95a08ab2b26317c": {
#       "model_name": "ToggleButtonModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {
#         "_dom_classes": [],
#         "icon": "globe",
#         "layout": "IPY_MODEL_2f207a4b4be4440d8e87820f6a4efee3",
#         "style": "IPY_MODEL_5887172a8a8645cd9381d415f166a58f",
#         "tooltip": "Search location/data"
#       }
#     },
#     "b8686ed963fa4e47a792e41bc8632de2": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {}
#     },
#     "123a3d18114a4254b2bef4ec55d4a5e5": {
#       "model_name": "ToggleButtonsStyleModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {
#         "button_width": "110px"
#       }
#     },
#     "bde110f1af5841ba9a638cf1b87bfa6c": {
#       "model_name": "ToggleButtonsModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {
#         "_dom_classes": [],
#         "_options_labels": [
#           "name/address",
#           "lat-lon",
#           "data"
#         ],
#         "icons": [],
#         "index": 0,
#         "layout": "IPY_MODEL_b8686ed963fa4e47a792e41bc8632de2",
#         "style": "IPY_MODEL_123a3d18114a4254b2bef4ec55d4a5e5",
#         "tooltips": [
#           "Search by place name or address",
#           "Search by lat-lon coordinates",
#           "Search Earth Engine data catalog"
#         ]
#       }
#     },
#     "d63561cb15c140d8bb0eca7f34d39d43": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {
#         "width": "340px"
#       }
#     },
#     "7c44d780d6c1440db58a8901b3dc6129": {
#       "model_name": "DescriptionStyleModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {}
#     },
#     "01eeb896905845468cbe117d2f25c0bc": {
#       "model_name": "TextModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {
#         "_dom_classes": [],
#         "layout": "IPY_MODEL_d63561cb15c140d8bb0eca7f34d39d43",
#         "placeholder": "Search by place name or address",
#         "style": "IPY_MODEL_7c44d780d6c1440db58a8901b3dc6129"
#       }
#     },
#     "2afb2f552e9d4e169bc06e28450cb3f3": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {
#         "max_height": "350px",
#         "max_width": "340px",
#         "overflow": "scroll"
#       }
#     },
#     "a657e0231bb346928248cd55bafc8d95": {
#       "model_name": "OutputModel",
#       "model_module": "@jupyter-widgets/output",
#       "model_module_version": "1.0.0",
#       "state": {
#         "_dom_classes": [],
#         "layout": "IPY_MODEL_2afb2f552e9d4e169bc06e28450cb3f3",
#         "outputs": []
#       }
#     },
#     "28e5773432c34a0087f9953b483e2244": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {}
#     },
#     "6b94b6263cca4205bdeeea24758c034a": {
#       "model_name": "DescriptionStyleModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {}
#     },
#     "64e6e736ade0414d94fbd8bae703977f": {
#       "model_name": "RadioButtonsModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {
#         "_dom_classes": [],
#         "_options_labels": [],
#         "layout": "IPY_MODEL_28e5773432c34a0087f9953b483e2244",
#         "style": "IPY_MODEL_6b94b6263cca4205bdeeea24758c034a"
#       }
#     },
#     "94516b2ce47e4173912a3c5586d7ee09": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {
#         "max_width": "279px",
#         "min_width": "279px"
#       }
#     },
#     "0a7684715fe34d0e81a5b78818ac14b8": {
#       "model_name": "DescriptionStyleModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {}
#     },
#     "62829db401da4f7c9e062b9b493520d6": {
#       "model_name": "DropdownModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {
#         "_dom_classes": [],
#         "_options_labels": [],
#         "layout": "IPY_MODEL_94516b2ce47e4173912a3c5586d7ee09",
#         "style": "IPY_MODEL_0a7684715fe34d0e81a5b78818ac14b8"
#       }
#     },
#     "35e4d9e722484dc78b356bfbdc03c8e6": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {
#         "max_width": "57px",
#         "min_width": "57px"
#       }
#     },
#     "e67140e6e7ab4cc3abf83ddbf890a8e9": {
#       "model_name": "ButtonStyleModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {}
#     },
#     "66fdd70aa0594bf0a2707a0bd9c084c9": {
#       "model_name": "ButtonModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {
#         "_dom_classes": [],
#         "button_style": "primary",
#         "description": "import",
#         "layout": "IPY_MODEL_35e4d9e722484dc78b356bfbdc03c8e6",
#         "style": "IPY_MODEL_e67140e6e7ab4cc3abf83ddbf890a8e9",
#         "tooltip": "Click to import the selected asset"
#       }
#     },
#     "4a1c891392ff4b3b868bf5cac4c4fea1": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {}
#     },
#     "c3cc3b5fd0ad42c9bbfe7111d5742e19": {
#       "model_name": "DescriptionStyleModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {}
#     },
#     "7f12ecaba9cd4b378eea632807cf03eb": {
#       "model_name": "HTMLModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {
#         "_dom_classes": [],
#         "layout": "IPY_MODEL_4a1c891392ff4b3b868bf5cac4c4fea1",
#         "style": "IPY_MODEL_c3cc3b5fd0ad42c9bbfe7111d5742e19"
#       }
#     },
#     "4a024ad99e494667a94b15e461994b5c": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {}
#     },
#     "4a8571e035c04f0597728e5fbfe0a5eb": {
#       "model_name": "HBoxModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {
#         "_dom_classes": [],
#         "children": [
#           "IPY_MODEL_66fdd70aa0594bf0a2707a0bd9c084c9",
#           "IPY_MODEL_62829db401da4f7c9e062b9b493520d6"
#         ],
#         "layout": "IPY_MODEL_4a024ad99e494667a94b15e461994b5c"
#       }
#     },
#     "6d9f3ada057e435687ef609edf56ce5a": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {}
#     },
#     "236793c4fe8c4512bbe6d051fe3a59f6": {
#       "model_name": "VBoxModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {
#         "_dom_classes": [],
#         "children": [
#           "IPY_MODEL_bde110f1af5841ba9a638cf1b87bfa6c",
#           "IPY_MODEL_01eeb896905845468cbe117d2f25c0bc"
#         ],
#         "layout": "IPY_MODEL_6d9f3ada057e435687ef609edf56ce5a"
#       }
#     },
#     "86f49ab8fd294657bc4c89d5416b997f": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {}
#     },
#     "d805220b8e1b49b586b627d7379bbd51": {
#       "model_name": "HBoxModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {
#         "_dom_classes": [],
#         "_view_count": 2,
#         "children": [
#           "IPY_MODEL_b0336fc0f3a340f2b95a08ab2b26317c"
#         ],
#         "layout": "IPY_MODEL_86f49ab8fd294657bc4c89d5416b997f"
#       }
#     },
#     "09d02fad79ab48a792c29c457821e53d": {
#       "model_name": "EventModel",
#       "model_module": "ipyevents",
#       "model_module_version": "2.0.1",
#       "state": {
#         "_supported_key_events": [
#           "keydown",
#           "keyup"
#         ],
#         "_supported_mouse_events": [
#           "click",
#           "auxclick",
#           "dblclick",
#           "mouseenter",
#           "mouseleave",
#           "mousedown",
#           "mouseup",
#           "mousemove",
#           "wheel",
#           "contextmenu",
#           "dragstart",
#           "drag",
#           "dragend",
#           "dragenter",
#           "dragover",
#           "dragleave",
#           "drop"
#         ],
#         "_supported_touch_events": [
#           "touchstart",
#           "touchend",
#           "touchmove",
#           "touchcancel"
#         ],
#         "source": "IPY_MODEL_d805220b8e1b49b586b627d7379bbd51",
#         "watched_events": [
#           "mouseenter",
#           "mouseleave"
#         ],
#         "xy": []
#       }
#     },
#     "5e0dc5710d9548b7aa3e43030ffbef33": {
#       "model_name": "LeafletWidgetControlModel",
#       "model_module": "jupyter-leaflet",
#       "model_module_version": "^0.17",
#       "state": {
#         "options": [
#           "position",
#           "transparent_bg"
#         ],
#         "widget": "IPY_MODEL_d805220b8e1b49b586b627d7379bbd51"
#       }
#     },
#     "cd78e4f38ee3400fa37e0ae6714eb8c8": {
#       "model_name": "LeafletZoomControlModel",
#       "model_module": "jupyter-leaflet",
#       "model_module_version": "^0.17",
#       "state": {
#         "options": [
#           "position",
#           "zoom_in_text",
#           "zoom_in_title",
#           "zoom_out_text",
#           "zoom_out_title"
#         ]
#       }
#     },
#     "e3c08e3abfb24560bac75965b8ba51b5": {
#       "model_name": "LeafletScaleControlModel",
#       "model_module": "jupyter-leaflet",
#       "model_module_version": "^0.17",
#       "state": {
#         "options": [
#           "imperial",
#           "max_width",
#           "metric",
#           "position",
#           "update_when_idle"
#         ],
#         "position": "bottomleft"
#       }
#     },
#     "111f070b77674428bd20e5ca4da4e1e2": {
#       "model_name": "LeafletFullScreenControlModel",
#       "model_module": "jupyter-leaflet",
#       "model_module_version": "^0.17",
#       "state": {
#         "options": [
#           "position"
#         ]
#       }
#     },
#     "635fa97945534a39af685a8582481b98": {
#       "model_name": "LeafletMeasureControlModel",
#       "model_module": "jupyter-leaflet",
#       "model_module_version": "^0.17",
#       "state": {
#         "_custom_units": {},
#         "active_color": "orange",
#         "options": [
#           "active_color",
#           "capture_z_index",
#           "completed_color",
#           "popup_options",
#           "position",
#           "primary_area_unit",
#           "primary_length_unit",
#           "secondary_area_unit",
#           "secondary_length_unit"
#         ],
#         "popup_options": {
#           "className": "leaflet-measure-resultpopup",
#           "autoPanPadding": [
#             10,
#             10
#           ]
#         },
#         "position": "bottomleft",
#         "primary_length_unit": "kilometers"
#       }
#     },
#     "ebe11ee949aa416ebf50197cbc291dad": {
#       "model_name": "LeafletTileLayerModel",
#       "model_module": "jupyter-leaflet",
#       "model_module_version": "^0.17",
#       "state": {
#         "attribution": "Google",
#         "max_zoom": 24,
#         "name": "Google Maps",
#         "options": [
#           "attribution",
#           "bounds",
#           "detect_retina",
#           "max_native_zoom",
#           "max_zoom",
#           "min_native_zoom",
#           "min_zoom",
#           "no_wrap",
#           "tile_size",
#           "tms",
#           "zoom_offset"
#         ],
#         "subitems": [],
#         "url": "https://mt1.google.com/vt/lyrs=m&x={x}&y={y}&z={z}"
#       }
#     },
#     "de3b1bc0c39d413f91203f3f7330c5e6": {
#       "model_name": "LeafletAttributionControlModel",
#       "model_module": "jupyter-leaflet",
#       "model_module_version": "^0.17",
#       "state": {
#         "options": [
#           "position",
#           "prefix"
#         ],
#         "position": "bottomright"
#       }
#     },
#     "0aef6fa213584c05ad4ca1708f4e2e60": {
#       "model_name": "LeafletDrawControlModel",
#       "model_module": "jupyter-leaflet",
#       "model_module_version": "^0.17",
#       "state": {
#         "circle": {
#           "shapeOptions": {
#             "color": "#3388ff"
#           }
#         },
#         "circlemarker": {},
#         "data": [],
#         "marker": {
#           "shapeOptions": {
#             "color": "#3388ff"
#           }
#         },
#         "options": [
#           "position"
#         ],
#         "polygon": {
#           "shapeOptions": {}
#         },
#         "polyline": {
#           "shapeOptions": {}
#         },
#         "rectangle": {
#           "shapeOptions": {
#             "color": "#3388ff"
#           }
#         }
#       }
#     },
#     "3b277f28dd8c4450b4ef4250b99b2d81": {
#       "model_name": "LeafletMarkerClusterModel",
#       "model_module": "jupyter-leaflet",
#       "model_module_version": "^0.17",
#       "state": {
#         "markers": [],
#         "name": "Marker Cluster",
#         "options": [
#           "disable_clustering_at_zoom",
#           "max_cluster_radius"
#         ],
#         "subitems": []
#       }
#     },
#     "f03926efc1eb43aea25d72ad9da37e73": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {}
#     },
#     "f66f4418dd3f45839765659e98756ac5": {
#       "model_name": "OutputModel",
#       "model_module": "@jupyter-widgets/output",
#       "model_module_version": "1.0.0",
#       "state": {
#         "_dom_classes": [],
#         "layout": "IPY_MODEL_f03926efc1eb43aea25d72ad9da37e73",
#         "outputs": []
#       }
#     },
#     "766289ef613546d1a2eed9d89b7b8b34": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {
#         "height": "auto",
#         "padding": "0px 0px 0px 4px",
#         "width": "auto"
#       }
#     },
#     "12237417083e4c9988fc8f4e52592ac9": {
#       "model_name": "DescriptionStyleModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {}
#     },
#     "b6fd9e01b75642a2a32780d7b94b2d8f": {
#       "model_name": "ToggleButtonModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {
#         "_dom_classes": [],
#         "button_style": "primary",
#         "icon": "info",
#         "layout": "IPY_MODEL_766289ef613546d1a2eed9d89b7b8b34",
#         "style": "IPY_MODEL_12237417083e4c9988fc8f4e52592ac9",
#         "tooltip": "Inspector"
#       }
#     },
#     "422fca7e64954815bb5f82c281f00484": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {
#         "height": "auto",
#         "padding": "0px 0px 0px 4px",
#         "width": "auto"
#       }
#     },
#     "762598bbdca8472bb93861666f5dfbdf": {
#       "model_name": "DescriptionStyleModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {}
#     },
#     "b1277b19942545ff8055d7b15c9e3281": {
#       "model_name": "ToggleButtonModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {
#         "_dom_classes": [],
#         "button_style": "primary",
#         "icon": "bar-chart",
#         "layout": "IPY_MODEL_422fca7e64954815bb5f82c281f00484",
#         "style": "IPY_MODEL_762598bbdca8472bb93861666f5dfbdf",
#         "tooltip": "Plotting"
#       }
#     },
#     "0fdfd068d4864b5589670115e5563aec": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {
#         "height": "auto",
#         "padding": "0px 0px 0px 4px",
#         "width": "auto"
#       }
#     },
#     "2fd466d03192443f91f02b65b858651f": {
#       "model_name": "DescriptionStyleModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {}
#     },
#     "ac73d69ed1a749fe8ac56443af9650f7": {
#       "model_name": "ToggleButtonModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {
#         "_dom_classes": [],
#         "button_style": "primary",
#         "icon": "eraser",
#         "layout": "IPY_MODEL_0fdfd068d4864b5589670115e5563aec",
#         "style": "IPY_MODEL_2fd466d03192443f91f02b65b858651f",
#         "tooltip": "Remove all drawn features"
#       }
#     },
#     "b4696358adc24d78b65d38c634fd34bb": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {
#         "height": "auto",
#         "padding": "0px 0px 0px 4px",
#         "width": "auto"
#       }
#     },
#     "8d16243ef8b141eab9f9278029609ed0": {
#       "model_name": "DescriptionStyleModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {}
#     },
#     "77b5dd5ab3ab4b888d6e3138fcdb011b": {
#       "model_name": "ToggleButtonModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {
#         "_dom_classes": [],
#         "button_style": "primary",
#         "icon": "folder-open",
#         "layout": "IPY_MODEL_b4696358adc24d78b65d38c634fd34bb",
#         "style": "IPY_MODEL_8d16243ef8b141eab9f9278029609ed0",
#         "tooltip": "Open local vector/raster data"
#       }
#     },
#     "a781e217e58a48dc8b2b4979d78d20f1": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {
#         "height": "auto",
#         "padding": "0px 0px 0px 4px",
#         "width": "auto"
#       }
#     },
#     "4076b35e13954d399fefdcc1ffb8fda0": {
#       "model_name": "DescriptionStyleModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {}
#     },
#     "954b92f7fe754e1586492ba405810732": {
#       "model_name": "ToggleButtonModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {
#         "_dom_classes": [],
#         "button_style": "primary",
#         "icon": "retweet",
#         "layout": "IPY_MODEL_a781e217e58a48dc8b2b4979d78d20f1",
#         "style": "IPY_MODEL_4076b35e13954d399fefdcc1ffb8fda0",
#         "tooltip": "Convert Earth Engine JavaScript to Python"
#       }
#     },
#     "c6bc8c7df5664c7bbab73efe0abb8126": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {
#         "height": "auto",
#         "padding": "0px 0px 0px 4px",
#         "width": "auto"
#       }
#     },
#     "3f96df7ad8b741fc94adffc4bab125ad": {
#       "model_name": "DescriptionStyleModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {}
#     },
#     "12a51e0993574ace98759859f1554e3b": {
#       "model_name": "ToggleButtonModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {
#         "_dom_classes": [],
#         "button_style": "primary",
#         "icon": "gears",
#         "layout": "IPY_MODEL_c6bc8c7df5664c7bbab73efe0abb8126",
#         "style": "IPY_MODEL_3f96df7ad8b741fc94adffc4bab125ad",
#         "tooltip": "WhiteboxTools for local geoprocessing"
#       }
#     },
#     "50b55880b4bc4d61a588fd922a3cd37d": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {
#         "height": "auto",
#         "padding": "0px 0px 0px 4px",
#         "width": "auto"
#       }
#     },
#     "c0a64bae5c144c32bd8768d96558407a": {
#       "model_name": "DescriptionStyleModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {}
#     },
#     "0bf2c207ad4d4767947156c51df6f922": {
#       "model_name": "ToggleButtonModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {
#         "_dom_classes": [],
#         "button_style": "primary",
#         "icon": "google",
#         "layout": "IPY_MODEL_50b55880b4bc4d61a588fd922a3cd37d",
#         "style": "IPY_MODEL_c0a64bae5c144c32bd8768d96558407a",
#         "tooltip": "GEE Toolbox for cloud computing"
#       }
#     },
#     "15d0986f3b064029b4e123215fb0c971": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {
#         "height": "auto",
#         "padding": "0px 0px 0px 4px",
#         "width": "auto"
#       }
#     },
#     "c88569f8b0f2447d85ebfdaaf21181c3": {
#       "model_name": "DescriptionStyleModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {}
#     },
#     "e41090737ac044749193082a628f6a99": {
#       "model_name": "ToggleButtonModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {
#         "_dom_classes": [],
#         "button_style": "primary",
#         "icon": "map",
#         "layout": "IPY_MODEL_15d0986f3b064029b4e123215fb0c971",
#         "style": "IPY_MODEL_c88569f8b0f2447d85ebfdaaf21181c3",
#         "tooltip": "Change basemap"
#       }
#     },
#     "33f31057f9cb4e598ba783ef6b3c8271": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {
#         "height": "auto",
#         "padding": "0px 0px 0px 4px",
#         "width": "auto"
#       }
#     },
#     "d09f99f021a442cca9804350bc88a458": {
#       "model_name": "DescriptionStyleModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {}
#     },
#     "46c8f927bbad4f1fab6c175051440fd3": {
#       "model_name": "ToggleButtonModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {
#         "_dom_classes": [],
#         "button_style": "primary",
#         "icon": "globe",
#         "layout": "IPY_MODEL_33f31057f9cb4e598ba783ef6b3c8271",
#         "style": "IPY_MODEL_d09f99f021a442cca9804350bc88a458",
#         "tooltip": "Create timelapse"
#       }
#     },
#     "7d7dbc60cff5494da03d1d091f2b44d1": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {
#         "height": "auto",
#         "padding": "0px 0px 0px 4px",
#         "width": "auto"
#       }
#     },
#     "b85a2be0382d46f8b8921bead7b9b867": {
#       "model_name": "DescriptionStyleModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {}
#     },
#     "c5e6b1052c094d13bea1fff80bc1bf55": {
#       "model_name": "ToggleButtonModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {
#         "_dom_classes": [],
#         "button_style": "primary",
#         "icon": "fast-forward",
#         "layout": "IPY_MODEL_7d7dbc60cff5494da03d1d091f2b44d1",
#         "style": "IPY_MODEL_b85a2be0382d46f8b8921bead7b9b867",
#         "tooltip": "Activate timeslider"
#       }
#     },
#     "530e3fc1bc3d420e8666e7755e9fc8ce": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {
#         "height": "auto",
#         "padding": "0px 0px 0px 4px",
#         "width": "auto"
#       }
#     },
#     "47448772849f491d9f508e656581323b": {
#       "model_name": "DescriptionStyleModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {}
#     },
#     "be0c3d62c54a42b98def3a4cb8d70e7f": {
#       "model_name": "ToggleButtonModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {
#         "_dom_classes": [],
#         "button_style": "primary",
#         "icon": "hand-o-up",
#         "layout": "IPY_MODEL_530e3fc1bc3d420e8666e7755e9fc8ce",
#         "style": "IPY_MODEL_47448772849f491d9f508e656581323b",
#         "tooltip": "Collect training samples"
#       }
#     },
#     "ff2428800e2f40f2a00f8d2d8a1eb2d1": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {
#         "height": "auto",
#         "padding": "0px 0px 0px 4px",
#         "width": "auto"
#       }
#     },
#     "fd444aa262af46ecb530f673ff0b5c87": {
#       "model_name": "DescriptionStyleModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {}
#     },
#     "082797d2cfcd4a51bb7a052cba7cc357": {
#       "model_name": "ToggleButtonModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {
#         "_dom_classes": [],
#         "button_style": "primary",
#         "icon": "line-chart",
#         "layout": "IPY_MODEL_ff2428800e2f40f2a00f8d2d8a1eb2d1",
#         "style": "IPY_MODEL_fd444aa262af46ecb530f673ff0b5c87",
#         "tooltip": "Creating and plotting transects"
#       }
#     },
#     "a680367224ac4622ac38fc00d8258441": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {
#         "height": "auto",
#         "padding": "0px 0px 0px 4px",
#         "width": "auto"
#       }
#     },
#     "aa2a0cc53a7b4619b489a1c118eecf91": {
#       "model_name": "DescriptionStyleModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {}
#     },
#     "ebb9c17ea8954c3ba2d185965843efd5": {
#       "model_name": "ToggleButtonModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {
#         "_dom_classes": [],
#         "button_style": "primary",
#         "icon": "random",
#         "layout": "IPY_MODEL_a680367224ac4622ac38fc00d8258441",
#         "style": "IPY_MODEL_aa2a0cc53a7b4619b489a1c118eecf91",
#         "tooltip": "Sankey plots"
#       }
#     },
#     "181bc869aacb41a2813acde11a03a0d1": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {
#         "height": "auto",
#         "padding": "0px 0px 0px 4px",
#         "width": "auto"
#       }
#     },
#     "4933a0cbc49f474ab4bec89164bcacc0": {
#       "model_name": "DescriptionStyleModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {}
#     },
#     "032198ab12344b7cb29b8fbe1feec2a4": {
#       "model_name": "ToggleButtonModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {
#         "_dom_classes": [],
#         "button_style": "primary",
#         "icon": "adjust",
#         "layout": "IPY_MODEL_181bc869aacb41a2813acde11a03a0d1",
#         "style": "IPY_MODEL_4933a0cbc49f474ab4bec89164bcacc0",
#         "tooltip": "Planet imagery"
#       }
#     },
#     "a0d1506961d243c9b79673389469452b": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {
#         "height": "auto",
#         "padding": "0px 0px 0px 4px",
#         "width": "auto"
#       }
#     },
#     "7e47d552dc3f4844958e65de602e0251": {
#       "model_name": "DescriptionStyleModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {}
#     },
#     "0b99b343df4543e9b9cb46a87d868d9b": {
#       "model_name": "ToggleButtonModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {
#         "_dom_classes": [],
#         "button_style": "primary",
#         "icon": "info-circle",
#         "layout": "IPY_MODEL_a0d1506961d243c9b79673389469452b",
#         "style": "IPY_MODEL_7e47d552dc3f4844958e65de602e0251",
#         "tooltip": "Get COG/STAC pixel value"
#       }
#     },
#     "6e548a78d859450798318b9018dddf6e": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {
#         "grid_gap": "1px 1px",
#         "grid_template_columns": "32px 32px 32px ",
#         "grid_template_rows": "32px 32px 32px 32px 32px ",
#         "padding": "5px",
#         "width": "109px"
#       }
#     },
#     "97e4eb19b3fb4035a9000705a85737a6": {
#       "model_name": "GridBoxModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {
#         "_dom_classes": [],
#         "children": [
#           "IPY_MODEL_b6fd9e01b75642a2a32780d7b94b2d8f",
#           "IPY_MODEL_b1277b19942545ff8055d7b15c9e3281",
#           "IPY_MODEL_ac73d69ed1a749fe8ac56443af9650f7",
#           "IPY_MODEL_77b5dd5ab3ab4b888d6e3138fcdb011b",
#           "IPY_MODEL_954b92f7fe754e1586492ba405810732",
#           "IPY_MODEL_12a51e0993574ace98759859f1554e3b",
#           "IPY_MODEL_0bf2c207ad4d4767947156c51df6f922",
#           "IPY_MODEL_e41090737ac044749193082a628f6a99",
#           "IPY_MODEL_46c8f927bbad4f1fab6c175051440fd3",
#           "IPY_MODEL_c5e6b1052c094d13bea1fff80bc1bf55",
#           "IPY_MODEL_be0c3d62c54a42b98def3a4cb8d70e7f",
#           "IPY_MODEL_082797d2cfcd4a51bb7a052cba7cc357",
#           "IPY_MODEL_ebb9c17ea8954c3ba2d185965843efd5",
#           "IPY_MODEL_032198ab12344b7cb29b8fbe1feec2a4",
#           "IPY_MODEL_0b99b343df4543e9b9cb46a87d868d9b"
#         ],
#         "layout": "IPY_MODEL_6e548a78d859450798318b9018dddf6e"
#       }
#     },
#     "aa6d70723d784e60b9916ccfd8126189": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {
#         "height": "28px",
#         "padding": "0px 0px 0px 4px",
#         "width": "28px"
#       }
#     },
#     "43917bec1e0d44e7916998c62622a581": {
#       "model_name": "DescriptionStyleModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {}
#     },
#     "db5ecee4ed4e47099a5638506c95a5c4": {
#       "model_name": "ToggleButtonModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {
#         "_dom_classes": [],
#         "icon": "wrench",
#         "layout": "IPY_MODEL_aa6d70723d784e60b9916ccfd8126189",
#         "style": "IPY_MODEL_43917bec1e0d44e7916998c62622a581",
#         "tooltip": "Toolbar"
#       }
#     },
#     "a9f94e0e592b467eb0cb57b7c248682a": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {
#         "height": "28px",
#         "width": "72px"
#       }
#     },
#     "88cb83bcd1eb45d6bda07985222707c3": {
#       "model_name": "DescriptionStyleModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {}
#     },
#     "2832477e137f45f6abbcee8741c2c2a9": {
#       "model_name": "ToggleButtonModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {
#         "_dom_classes": [],
#         "icon": "server",
#         "layout": "IPY_MODEL_a9f94e0e592b467eb0cb57b7c248682a",
#         "style": "IPY_MODEL_88cb83bcd1eb45d6bda07985222707c3",
#         "tooltip": "Layers"
#       }
#     },
#     "f8ab55c5cb6a4559ad20e24e7728f7a2": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {}
#     },
#     "b9281337c0f34acf82cf7e337a5229cb": {
#       "model_name": "VBoxModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {
#         "_dom_classes": [],
#         "_view_count": 2,
#         "children": [
#           "IPY_MODEL_db5ecee4ed4e47099a5638506c95a5c4"
#         ],
#         "layout": "IPY_MODEL_f8ab55c5cb6a4559ad20e24e7728f7a2"
#       }
#     },
#     "f817f8f23dcb4d5287b36584beb24d7a": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {}
#     },
#     "088fd2061bb743c28f9e2b4bfe8c11ae": {
#       "model_name": "HBoxModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {
#         "_dom_classes": [],
#         "children": [
#           "IPY_MODEL_2832477e137f45f6abbcee8741c2c2a9",
#           "IPY_MODEL_db5ecee4ed4e47099a5638506c95a5c4"
#         ],
#         "layout": "IPY_MODEL_f817f8f23dcb4d5287b36584beb24d7a"
#       }
#     },
#     "fbd722e2a949461883bc875f14ba3ab7": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {}
#     },
#     "85396b6e218444ce9cf934656cf08dc2": {
#       "model_name": "VBoxModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {
#         "_dom_classes": [],
#         "children": [
#           "IPY_MODEL_97e4eb19b3fb4035a9000705a85737a6"
#         ],
#         "layout": "IPY_MODEL_fbd722e2a949461883bc875f14ba3ab7"
#       }
#     },
#     "f779fc200257461a9fc6ec166e7209a2": {
#       "model_name": "EventModel",
#       "model_module": "ipyevents",
#       "model_module_version": "2.0.1",
#       "state": {
#         "_supported_key_events": [
#           "keydown",
#           "keyup"
#         ],
#         "_supported_mouse_events": [
#           "click",
#           "auxclick",
#           "dblclick",
#           "mouseenter",
#           "mouseleave",
#           "mousedown",
#           "mouseup",
#           "mousemove",
#           "wheel",
#           "contextmenu",
#           "dragstart",
#           "drag",
#           "dragend",
#           "dragenter",
#           "dragover",
#           "dragleave",
#           "drop"
#         ],
#         "_supported_touch_events": [
#           "touchstart",
#           "touchend",
#           "touchmove",
#           "touchcancel"
#         ],
#         "source": "IPY_MODEL_b9281337c0f34acf82cf7e337a5229cb",
#         "watched_events": [
#           "mouseenter",
#           "mouseleave"
#         ],
#         "xy": []
#       }
#     },
#     "5f12660e0586463895d2388bb617f3d2": {
#       "model_name": "LeafletWidgetControlModel",
#       "model_module": "jupyter-leaflet",
#       "model_module_version": "^0.17",
#       "state": {
#         "options": [
#           "position",
#           "transparent_bg"
#         ],
#         "position": "topright",
#         "widget": "IPY_MODEL_b9281337c0f34acf82cf7e337a5229cb"
#       }
#     },
#     "5dea01f46cfe4f169d746b0bba05397c": {
#       "model_name": "LeafletTileLayerModel",
#       "model_module": "jupyter-leaflet",
#       "model_module_version": "^0.17",
#       "state": {
#         "attribution": "Google Earth Engine",
#         "max_zoom": 24,
#         "name": "SRTM",
#         "options": [
#           "attribution",
#           "bounds",
#           "detect_retina",
#           "max_native_zoom",
#           "max_zoom",
#           "min_native_zoom",
#           "min_zoom",
#           "no_wrap",
#           "tile_size",
#           "tms",
#           "zoom_offset"
#         ],
#         "subitems": [],
#         "url": "https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/c62bbabe1c567c732f0f9f38f901a3af-eb3e9933df1fcee2f403fdbc05628a66/tiles/{z}/{x}/{y}"
#       }
#     },
#     "f5d57eec294a45b882f832b879998233": {
#       "model_name": "LeafletLayersControlModel",
#       "model_module": "jupyter-leaflet",
#       "model_module_version": "^0.17",
#       "state": {
#         "options": [
#           "position"
#         ],
#         "position": "topright"
#       }
#     },
#     "f97c39e746c84af0aa0fafdfe3b0d1fb": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {}
#     },
#     "5ca2a41e24a449868eff953fc8ebf723": {
#       "model_name": "DescriptionStyleModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {}
#     },
#     "3f9353e8844a4e02a90b6dbf08fe10cf": {
#       "model_name": "HTMLModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "1.5.0",
#       "state": {
#         "_dom_classes": [],
#         "layout": "IPY_MODEL_f97c39e746c84af0aa0fafdfe3b0d1fb",
#         "style": "IPY_MODEL_5ca2a41e24a449868eff953fc8ebf723",
#         "value": "<!DOCTYPE html>\n<html lang=\"en\">\n<head>\n    <meta charset=\"UTF-8\">\n    <title>My Map</title>\n</head>\n<body>\n\n\n\u003c!-- Load require.js. Delete this if your page already loads require.js -->\n\u003cscript src=\"https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.4/require.min.js\" integrity=\"sha256-Ae2Vz/4ePdIu6ZyI/5ZGsYnb+m0JlOmKPjt6XZ9JJkA=\" crossorigin=\"anonymous\">\u003c/script>\n\u003cscript src=\"https://unpkg.com/@jupyter-widgets/html-manager@^0.20.0/dist/embed-amd.js\" crossorigin=\"anonymous\">\u003c/script>\n\n\u003cscript type=\"application/vnd.jupyter.widget-state+json\">\n{\n  \"version_major\": 2,\n  \"version_minor\": 0,\n  \"state\": {\n    \"fdbe45f6c396417991d439a3c724820e\": {\n      \"model_name\": \"LeafletMapStyleModel\",\n      \"model_module\": \"jupyter-leaflet\",\n      \"model_module_version\": \"^0.17\",\n      \"state\": {}\n    },\n    \"a5dfa6692266408696c246032e9f03fd\": {\n      \"model_name\": \"LeafletMapStyleModel\",\n      \"model_module\": \"jupyter-leaflet\",\n      \"model_module_version\": \"^0.17\",\n      \"state\": {\n        \"cursor\": \"move\"\n      }\n    },\n    \"b51fec4c6aeb4dbba3356f30bd4d0a1a\": {\n      \"model_name\": \"LeafletTileLayerModel\",\n      \"model_module\": \"jupyter-leaflet\",\n      \"model_module_version\": \"^0.17\",\n      \"state\": {\n        \"attribution\": \"&copy; <a href=\\\"https://www.openstreetmap.org/copyright\\\">OpenStreetMap</a> contributors\",\n        \"base\": true,\n        \"max_zoom\": 19,\n        \"min_zoom\": 1,\n        \"name\": \"OpenStreetMap.Mapnik\",\n        \"options\": [\n          \"attribution\",\n          \"bounds\",\n          \"detect_retina\",\n          \"max_native_zoom\",\n          \"max_zoom\",\n          \"min_native_zoom\",\n          \"min_zoom\",\n          \"no_wrap\",\n          \"tile_size\",\n          \"tms\",\n          \"zoom_offset\"\n        ],\n        \"subitems\": [],\n        \"url\": \"https://tile.openstreetmap.org/{z}/{x}/{y}.png\"\n      }\n    },\n    \"15f3d8a3bd6f4c4e9cf53ffdd9709ffe\": {\n      \"model_name\": \"LayoutModel\",\n      \"model_module\": \"@jupyter-widgets/base\",\n      \"model_module_version\": \"1.2.0\",\n      \"state\": {\n        \"height\": \"880px\",\n        \"width\": \"100%\"\n      }\n    },\n    \"3a4aacb760b84fe1a6dc39c45dd91954\": {\n      \"model_name\": \"LeafletMapStyleModel\",\n      \"model_module\": \"jupyter-leaflet\",\n      \"model_module_version\": \"^0.17\",\n      \"state\": {}\n    },\n    \"63491f137df4446fb27e9177d8a54663\": {\n      \"model_name\": \"LeafletMapModel\",\n      \"model_module\": \"jupyter-leaflet\",\n      \"model_module_version\": \"^0.17\",\n      \"state\": {\n        \"_dom_classes\": [],\n        \"bottom\": 775.0,\n        \"center\": [\n          12.897489183755892,\n          169.80468750000003\n        ],\n        \"controls\": [\n          \"IPY_MODEL_5e0dc5710d9548b7aa3e43030ffbef33\",\n          \"IPY_MODEL_cd78e4f38ee3400fa37e0ae6714eb8c8\",\n          \"IPY_MODEL_e3c08e3abfb24560bac75965b8ba51b5\",\n          \"IPY_MODEL_111f070b77674428bd20e5ca4da4e1e2\",\n          \"IPY_MODEL_635fa97945534a39af685a8582481b98\",\n          \"IPY_MODEL_de3b1bc0c39d413f91203f3f7330c5e6\",\n          \"IPY_MODEL_0aef6fa213584c05ad4ca1708f4e2e60\",\n          \"IPY_MODEL_5f12660e0586463895d2388bb617f3d2\",\n          \"IPY_MODEL_f5d57eec294a45b882f832b879998233\"\n        ],\n        \"crs\": {\n          \"name\": \"EPSG3857\",\n          \"custom\": false\n        },\n        \"default_style\": \"IPY_MODEL_fdbe45f6c396417991d439a3c724820e\",\n        \"dragging_style\": \"IPY_MODEL_a5dfa6692266408696c246032e9f03fd\",\n        \"east\": 242.92968750000003,\n        \"layers\": [\n          \"IPY_MODEL_b51fec4c6aeb4dbba3356f30bd4d0a1a\",\n          \"IPY_MODEL_ebe11ee949aa416ebf50197cbc291dad\",\n          \"IPY_MODEL_5dea01f46cfe4f169d746b0bba05397c\"\n        ],\n        \"layout\": \"IPY_MODEL_1 ...
#       }
#     }
#   }
# }
# </script>
# <script type="application/vnd.jupyter.widget-view+json">
# {"version_major": 2, "version_minor": 0, "model_id": "63491f137df4446fb27e9177d8a54663"}
# </script>
#
# </body>
# </html>
