# %% [markdown]
# ## ALL AT ONCE TEST

# %%
import geemap

# Get height from front-end
height = 300

# Authorize my GEE account
geemap.ee_initialize()

# Create a map using GEE API and geemap
Map = geemap.Map(
    center=[21.79, 70.87], 
    zoom=3, 
    zoom_ctrl = True, 
    data_ctrl = False,
    fullscreen_ctrl = False,
    search_ctrl = False,
    draw_ctrl = False,
    scale_ctrl = False,
    measure_ctrl = False,
    toolbar_ctrl = False,
    layer_ctrl = False,
    attribution_ctrl = False,
    )

image = geemap.ee.Image('USGS/SRTMGL1_003')
vis_params = {
    'min': 0,
    'max': 6000,
    'palette': ['006633', 'E5FFCC', '662A00', 'D8D8D8', 'F5F5F5'],
}
Map.addLayer(image, vis_params, 'SRTM')

# Get my HTML string
html_string = Map.to_html(title='My Map', width='100%', height=f'{height}px')

# %%
import requests
res = requests.post(f'http://192.168.8.125:3002/get_thumbnail', data={'data': html_string})
print(res.text)
# Out:
# ...

# %% [markdown]
# ## ONE BY ONE TEST

# %%
import ee
import geemap
geemap.ee_initialize()

# %%
Map = geemap.Map()

# %%
Map = geemap.Map(center=[40, -100], zoom=4, height=600)
Map
# Out:
# Map(center=[40, -100], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(T…

# %%
Map = geemap.Map(center=[21.79, 70.87], zoom=3)
image = ee.Image('USGS/SRTMGL1_003')
vis_params = {
    'min': 0,
    'max': 6000,
    'palette': ['006633', 'E5FFCC', '662A00', 'D8D8D8', 'F5F5F5'],
}
Map.addLayer(image, vis_params, 'SRTM')
Map

# %%
import os

current_directory = os.getcwd()

download_dir = os.path.abspath(os.path.join(current_directory, '../golden_eye_draft/assets'))
print(download_dir)
# Out:
# C:\Users\fsuli\Programming\100PROJECTS\GIS-GEE-Project\golden_eye_draft\assets

# %%
html_file = os.path.join(download_dir, 'my_map_one.html')
Map.to_html(filename=html_file, title='My Map', width='100%', height='300px')

# %%
import sys
print(sys.version)
# Out:
# 3.9.12 | packaged by conda-forge | (main, Mar 24 2022, 23:18:12) [MSC v.1929 64 bit (AMD64)]

# %% [markdown]
# ## Keep this for reference
# ### Good html-manager vs bad

# %%
from ipywidgets import HTML

# %%
# Good stuff

print(HTML(value = Map.to_html()).value[:700])
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>My Map</title>
# </head>
# <body>
#
#
# <!-- Load require.js. Delete this if your page already loads require.js -->
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.4/require.min.js" integrity="sha256-Ae2Vz/4ePdIu6ZyI/5ZGsYnb+m0JlOmKPjt6XZ9JJkA=" crossorigin="anonymous"></script>
# <script src="https://unpkg.com/@jupyter-widgets/html-manager@^0.20.0/dist/embed-amd.js" crossorigin="anonymous"></script>
#
# <script type="application/vnd.jupyter.widget-state+json">
# {
#   "version_major": 2,
#   "version_minor": 0,
#   "state": {
#     "d996d4c36be742f8b6d19fcad1acf734": {
#       "model_name": "LeafletMapStyleModel",

# %%
# Bad stuff

print(HTML(value = Map.to_html()).value[:700])
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>My Map</title>
# </head>
# <body>
#
#
# <!-- Load require.js. Delete this if your page already loads require.js -->
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.4/require.min.js" integrity="sha256-Ae2Vz/4ePdIu6ZyI/5ZGsYnb+m0JlOmKPjt6XZ9JJkA=" crossorigin="anonymous"></script>
# <script src="https://cdn.jsdelivr.net/npm/@jupyter-widgets/html-manager@^1.0.1/dist/embed-amd.js" crossorigin="anonymous"></script>
#
# <script type="application/vnd.jupyter.widget-state+json">
# {
#   "version_major": 2,
#   "version_minor": 0,
#   "state": {
#     "dab4fb15c18a4d60866259268b27cae3": {
#       "model_name": "LeafletMapStyleMod

# %%
Map.to_html()
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n    <meta charset="UTF-8">\n    <title>My Map</title>\n</head>\n<body>\n\n\n<!-- Load require.js. Delete this if your page already loads require.js -->\n<script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.4/require.min.js" integrity="sha256-Ae2Vz/4ePdIu6ZyI/5ZGsYnb+m0JlOmKPjt6XZ9JJkA=" crossorigin="anonymous"></script>\n<script src="https://unpkg.com/@jupyter-widgets/html-manager@^0.20.1/dist/embed-amd.js" crossorigin="anonymous"></script>\n\n<script type="application/vnd.jupyter.widget-state+json">\n{\n  "version_major": 2,\n  "version_minor": 0,\n  "state": {\n    "563b3bf1aef1424d92d6d147ec24cdc1": {\n      "model_name": "LeafletMapStyleModel",\n      "model_module": "jupyter-leaflet",\n      "model_module_version": "^0.17",\n      "state": {}\n    },\n    "f16499b6d3724b138742c2b5ce504bd3": {\n      "model_name": "LeafletMapStyleModel",\n      "model_module": "jupyter-leaflet",\n      "model_module_version": "^0.17",\n   
# ...

# %%
ee.Authenticate()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=Z3XqKF4VXeoqEJAPgd6brN02wd_DwRjuQFhTiBscluY&tc=0x6NudK9pEg3sP8iKC7U9irIsBBihFxZbf8vqDkkR-s&cc=R7iXhcOq9K-FqKETjVDrLnXZkiLnx1g2dYMKDLyhEdk>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=Z3XqKF4VXeoqEJAPgd6brN02wd_DwRjuQFhTiBscluY&tc=0x6NudK9pEg3sP8iKC7U9irIsBBihFxZbf8vqDkkR-s&cc=R7iXhcOq9K-FqKETjVDrLnXZkiLnx1g2dYMKDLyhEdk</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>

# %% [markdown]
# ## AUTH TESTS

# %%
import ee
import google.auth

# credentials, project_id = google.auth.
test = "AuthCredential(providerId: google.com, signInMethod: google.com, token: null, accessToken: ya29.a0AbVbY6Mm-XBxjUBi9ut85q3m3RjLk0i3s7MJg_uLC9CmyeVNNshmTfEUj-ZFP9U-t_YKMxi1zjtx7Wz2jmryGhkvoeWR600Zqc7P5161mKM9xktmIjUl03fg72s2K0nDPvrKQDTO5P0xoa9F9J52AbBxl92lswaCgYKAUMSARASFQFWKvPlCnGW8nsDdQQUsEkqnPcd5A0165)"
# print(credentials)

# credentials, project_id = google.auth.()
ee.Initialize( credentials = "ya29.a0AbVbY6Mm-XBxjUBi9ut85q3m3RjLk0i3s7MJg_uLC9CmyeVNNshmTfEUj-ZFP9U-t_YKMxi1zjtx7Wz2jmryGhkvoeWR600Zqc7P5161mKM9xktmIjUl03fg72s2K0nDPvrKQDTO5P0xoa9F9J52AbBxl92lswaCgYKAUMSARASFQFWKvPlCnGW8nsDdQQUsEkqnPcd5A0165")

# %%
credentials, project_id = google.auth.load_credentials_from_dict()
ee.Initialize(credentials, project='your-project')
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 credentials, project_id = google.auth.default()
#       2 ee.Initialize(credentials, project='your-project')
#
# File c:\Users\fsuli\anaconda3\envs\flaskenv\Lib\site-packages\google\auth\_default.py:692, in default(scopes, request, quota_project_id, default_scopes)
#     684             _LOGGER.warning(
#     685                 "No project ID could be determined. Consider running "
#     686                 "`gcloud config set project` or setting the %s "
#     687                 "environment variable",
#     688                 environment_vars.PROJECT,
#     689             )
#     690         return credentials, effective_project_id
# --> 692 raise exceptions.DefaultCredentialsError(_CLOUD_SDK_MISSING_CREDENTIALS)
#
# ...
